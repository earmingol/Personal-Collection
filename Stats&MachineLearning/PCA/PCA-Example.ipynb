# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from PCA_algorithms import PCAResults, PlotLoadings

# %matplotlib inline

# %% [markdown]
# # Data

# %%
data = load_iris()

# %%
X = data['data']

# %%
labels = data['feature_names']

# %% [markdown]
# # Run PCA

# %%
results = PCAResults(X)

# %% [markdown]
# # Visualize results

# %%
fig, ax = results.plots(labels,
                        PC1=1,
                        PC2=2
                        )
